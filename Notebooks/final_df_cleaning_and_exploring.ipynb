# %%
import pandas as pd

# %%
# import final_df
path = r'/Users/gabbyvinco/Desktop/companies_final_451.csv'
final_df = pd.read_csv(path, index_col=None, header=0)

# %%
# import unique_companies_df
other_path = r'/Users/gabbyvinco/Desktop/unique_companies.csv'
unique_companies_df = pd.read_csv(other_path, index_col=None, header=0)

# %%
final_df
# Out:
#                               organizationName       orgID  \
# 0                 Elia Transmission Belgium NV  5071549731
# 1    Deutsche Telekom International Finance BV  4296543170
# 2                            innogy Finance BV  4296653814
# 3                EnBW International Finance BV  4296930961
# 4                E On International Finance BV  4296072717
# ..                                         ...         ...
# 446                   Reseaux Cables De France  4296680912
# 447                   Reseaux Cables De France  4296858525
# 448               Befimmo Property Services SA  5067178704
# 449         Brussels Airport Terminal Co SA NV  4296730050
# 450                           Solvay France SA  4296152148
#
#                            orgID_URL               orgSubtype  \
# 0    https://permid.org/1-5071549731                  Company
# 1    https://permid.org/1-4296543170  Special Purpose Vehicle
# 2    https://permid.org/1-4296653814  Special Purpose Vehicle
# ...

# %%
unique_companies_df
# Out:
#                                           0
# 0                 Elia Transmission Belgium
# 1                               Enodia SCRL
# 2               Groupe Bruxelles Lambert SA
# 3              Fluvius System Operator CVBA
# 4                                BEFIMMO SA
# ..                                      ...
# 355                        Esselunga S.p.A.
# 356                               ERG S.p.A
# 357     RAI - RADIOTELEVISIONE ITALIANA SPA
# 358  Infrastrutture Wireless Italiane S.p.A
# 359                   Poste Italiane S.p.A.
#
# [360 rows x 1 columns]

# %%
unique_list = unique_companies_df.values.tolist()

# %%
unique_list[0]
# Out:
# ['Elia Transmission Belgium']

# %%
first_word_list = []

# %%
for n in range(len(unique_list)):
    split_name = unique_list[n][0].split()
    first_name = split_name[0]
    first_word_list.append(first_name)

# %%
first_word_list
# Out:
# ['Elia',
#  'Enodia',
#  'Groupe',
#  'Fluvius',
#  'BEFIMMO',
#  'Elia',
#  'Anheuser-Busch',
#  'Brussels',
#  'Apetra',
#  'Barry',
#  'Solvay',
#  'Lonza',
#  'ENI',
#  'VGP',
#  'JAB',
#  'TRATON',
#  'SIX',
#  'Stellantis',
#  'Brisa',
#  'EDP',
#  'Metropolitano',
#  'NOS',
#  'Telecom',
#  'Nederlandse',
#  'EDP',
#  'TenneT',
#  'ENEXIS',
#  'Alliander',
#  'Akzo',
#  'Nestl',
#  'Wolters',
#  'ASML',
#  'Zpadoslovensk',
#  'Holcim',
#  'Heineken',
#  'Koninklijke',
#  'Shell',
#  'Airbus',
#  'SPP-Distribucia,',
#  'Citycon',
#  'CNH',
#  'EXOR',
#  'Novartis',
#  'Urenco',
#  'Eurofins',
#  'Unilever',
#  'SPP',
#  'REN',
#  'Roche',
#  'NN',
#  'Michelin',
#  'Adecco',
#  'Royal',
#  'Coca',
#  'RELX',
#  'ABB',
#  'Bunge',
#  'Aroundtown',
#  'Koninklijke',
#  'Whirlpool',
#  'Aegon',
#  'WPC',
#  'HeidelbergCement',
#  'Compass',
#  'ADLER',
#  'Grand',
#  'Koninklijke',
#  'John',
#  'Koninklijke',
#  'Stedin',
#  'PostNL',
#  'ArcelorMittal',
#  'Euronext',
# ...

# %%
orgNames_list = final_df['organizationName'].values.tolist()

# %%
for word in first_word_list:
    for 

for o in range(len(final_df)):
    final_df["col1"].str.contains("A")
